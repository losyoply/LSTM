# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch.nn as nn
import csv
import pandas as pd
from keras.callbacks import History
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout,Input
# import tensorflow as tf
# print(tf.__file__)
from pandas import read_csv
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["axes.unicode_minus"]=False

# %%
def generate_diff(input_array):
    output_array = [0]  # 初始值设为0
    
    for i in range(1, len(input_array)):
        output_array.append(input_array[i] - input_array[i - 1])
        
    return output_array
    
# load data
def parse(x):
    return datetime.strptime(x, '%Y/%m/%d')

dataset = read_csv('2012-2016.csv')
dataset['DateTime'] = pd.to_datetime(dataset['Date'] + ' ' + dataset['Time'])



# # 将 Time 列转换为时间格式
# dataset['Time'] = pd.to_datetime(dataset['Time'])

# # 指定时间范围
# start_time = pd.to_datetime("8:44:00").time()
# end_time = pd.to_datetime("10:30:10").time()

# 选择指定时间范围内的数据
# selected_data = dataset[(dataset['Time'].dt.time >= start_time) & (dataset['Time'].dt.time <= end_time)]
selected_data=dataset


###### 新的一天，将diff设置为0
#selected_data.loc[dataset['Date'] != dataset['Date'].shift(), ['Diff','Diff_Pct']] = 0

#######
selected_data.set_index('DateTime', inplace=True)
selected_data.drop(columns=['Time','Date'], inplace=True)

selected_data=selected_data.dropna()
# summarize first 5 rows
# print(selected_data.head(5))

df_resampled = selected_data.resample('10T').agg({
    'Open': 'first',
    'High': 'max',
    'Low': 'min',
    'Close': 'last',
    'TotalVolume': 'sum',
})
df_resampled['Diff_Pct'] = df_resampled['Close'].pct_change()
df_resampled['Diff'] = df_resampled['Close'].diff()
df_resampled["C-L"] = df_resampled["Close"] - df_resampled["Low"]
df_resampled["H-L"] = df_resampled["High"] - df_resampled["Low"]
df_resampled["%K"] = (df_resampled["C-L"] / df_resampled["H-L"]) * 100
# 计算%D指标，这里采用3周期的简单移动平均
df_resampled["%D"] = df_resampled["%K"].rolling(window=3).mean()

# RSI
df_resampled['Gain'] = df_resampled['Diff'].apply(lambda x: x if x > 0 else 0)
df_resampled['Loss'] = df_resampled['Diff'].apply(lambda x: -x if x < 0 else 0)

# 计算平均的上涨和下跌价格变化（使用14天的时间窗口）
window = 14
df_resampled['AvgGain'] = df_resampled['Gain'].rolling(window=window).mean()
df_resampled['AvgLoss'] = df_resampled['Loss'].rolling(window=window).mean()
# 计算相对强度（RS）
df_resampled['RS'] = df_resampled['AvgGain'] / df_resampled['AvgLoss']
# 计算RSI
df_resampled['RSI'] = 100 - (100 / (1 + df_resampled['RS']))
df_resampled.drop(columns=['RS','AvgLoss','AvgGain','Gain', 'Loss'], inplace=True)

# 如果你想要去掉NaN值，可以使用以下代碼
df_resampled = df_resampled.dropna()
print(df_resampled[:6])


# # save to file
# Out:
#                        Open    High     Low   Close  TotalVolume  Diff_Pct  \
# DateTime
# 2012-01-02 10:50:00  6987.0  6989.0  6977.0  6979.0         1773 -0.001145
# 2012-01-02 11:00:00  6979.0  6980.0  6951.0  6960.0         6665 -0.002722
# 2012-01-02 11:10:00  6960.0  6965.0  6953.0  6959.0         2041 -0.000144
# 2012-01-02 11:20:00  6959.0  6967.0  6956.0  6960.0         1484  0.000144
# 2012-01-02 11:30:00  6960.0  6962.0  6950.0  6958.0         1929 -0.000287
# 2012-01-02 11:40:00  6958.0  6960.0  6945.0  6947.0         2194 -0.001581
#
#                      Diff  C-L   H-L         %K         %D        RSI
# DateTime
# 2012-01-02 10:50:00  -8.0  2.0  12.0  16.666667  50.186741  32.352941
# 2012-01-02 11:00:00 -19.0  9.0  29.0  31.034483  33.547442  27.272727
# 2012-01-02 11:10:00  -1.0  6.0  12.0  50.000000  32.567050   7.291667
# 2012-01-02 11:20:00   1.0  4.0  11.0  36.363636  39.132706   6.315789
# 2012-01-02 11:30:00  -2.0  8.0  12.0  66.666667  51.010101   7.407407
# 2012-01-02 11:40:00 -11.0  2.0  15.0  13.333333  38.787879   5.494505

# %%
# sns.set_style("darkgrid")
# plt.figure(figsize=(15,9))
# plt.plot(selected_data.index,selected_data[['Close']])
# # plt.xticks(range(0,dataset.shape[0], 10000), dataset.index[::10000],rotation=45)
# plt.title("price", fontsize=18, fontweight='bold')
# plt.xlabel("date", fontsize=18)
# plt.ylabel("close", fontsize=18)
# plt.show()

# plt.figure(figsize=(16,4))
# plt.plot(selected_data['LogDiff'])

# %%
def generate_y_for10(input_array):
    output_array = [] 
    
    for i in range(0, len(input_array)):
        if input_array[i]>0:
            output_array.append(2)
        elif input_array[i]<0:
            output_array.append(1)
        else:
            output_array.append(0)
    
    return output_array

def generate_y(input_array):
    output_array = []  # 初始值设为0
    
    for i in range(0, len(input_array)-1):
        output_array.append(input_array[i+1] - input_array[i])
        
    return output_array
    

values = df_resampled.values
# ensure all data is float
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0,1))
#############################################
# scaler_diff=MinMaxScaler(feature_range=(-1,1))
# t=scaler_diff.fit_transform(values[:,-1].reshape(-1,1))
# print(t)
#############################################
# normalize features
scaled = scaler.fit_transform(values)#待檢查
print(scaled)

# ##漲跌平
class_indices= generate_y_for10(values[:,5]) #diff
# 确定类别的数量
num_classes = max(class_indices) + 1

# 使用NumPy创建一个全零数组，形状为(数组长度, 类别数量)
y_label = np.zeros((len(class_indices), num_classes))
# 将对应的位置设置为1
y_label[np.arange(len(class_indices)), class_indices] = 1
# y_label=generate_y(values[:,3])#close明天相對今天增長量
print(y_label[:5])
# ##

# # 新增一列(diff 正規過後)
# # diff_n= np.array(generate_diff(scaled[:,3]))#close
# diff_n=
# # 创建布尔掩码
# mask = values[:,5] == 0.0
# # 使用布尔掩码将 b 中对应位置的值设为 0
# diff_n[mask] = 0.0
# x_label=np.hstack((scaled[:,[0,1,2,3,4,6,7]], diff_n.reshape(-1, 1)))
###########################
x_label=scaled[:,[0,1,2,3,5,7,8,9,10,11]]
# print(scaled[:5])
print(x_label[208:215])
# Out:
# [[0.06228781 0.05845976 0.06031537 ... 0.16666666 0.5018674  0.3235294 ]
#  [0.05982113 0.05567575 0.05227351 ... 0.31034482 0.33547443 0.27272728]
#  [0.05396223 0.05103612 0.05289197 ... 0.5        0.3256705  0.07291666]
#  ...
#  [0.76349044 0.76337767 0.7664707  ... 0.5        0.7        0.79310346]
#  [0.7644155  0.762759   0.7664707  ... 0.16666666 0.4888889  0.64      ]
#  [0.76379895 0.7621405  0.7664707  ... 0.5        0.3888889  0.59090906]]
# [[0. 1. 0.]
#  [0. 1. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]
#  [0. 1. 0.]]
# [[0.12272573 0.12248683 0.12341475 0.12326217 0.44769368 0.04663212
#   0.05761316 0.59999996 0.7        0.70731705]
#  [0.12488437 0.12063098 0.12403345 0.12233543 0.41710904 0.02072539
#   0.02469136 0.57142854 0.6682539  0.6153846 ]
#  [0.12365079 0.12032175 0.12465191 0.12202668 0.42322052 0.00518135
#   0.01234568 0.25       0.4738095  0.57894737]
#  [0.12365079 0.12032175 0.12403345 0.12264442 0.43239433 0.02590673
#   0.02057613 0.8333333  0.5515873  0.6153846 ]
#  [0.12426758 0.1215589  0.12557983 0.12388015 0.4385071  0.02072539
#   0.0164609  0.79999995 0.62777776 0.63414633]
#  [0.12550092 0.1221776  0.12619853 0.12326217 0.42016712 0.
#   0.0164609  0.         0.54444444 0.6666666 ]
#  [0.12488437 0.12124968 0.1252706  0.12295341 0.4232218  0.01036269
#   0.0164609  0.39999998 0.39999998 0.6315789 ]]

# %%
# values = selected_data.values
# # ensure all data is float
# values = values.astype('float32')
# scaler = MinMaxScaler(feature_range=(0,1)).fit(values)
# x_label=scaled=scaler.transform(values)
# print(x_label[:5])
# y_label=[x[5] for x in scaled]
# y_label = y_label[1:]
# print(y_label[:5])
# print(y_label[0])

# qq=np.zeros((len(y_label),8))
# qq[:,5]=np.array(y_label)
# print(qq)
# qqq=scaler.inverse_transform(qq)
# print(qqq[0,5])

# %%
def split_windows(data,label, seq_length):
    x=[]
    y=[]
    for i in range(len(data)-seq_length-1):
        _x=data[i:(i+seq_length),:]
        _y=label[i+seq_length]
        x.append(_x)
        y.append(_y)
    x,y=np.array(x),np.array(y)
    # print('x.shape,y.shape=\n',x.shape,y.shape)
    return x,y

def split_data(x, y, split_ratio):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=split_ratio, shuffle=False)
    return x_train, y_train, x_test, y_test

# %%
windowed_x, windowed_y = split_windows(x_label, y_label, 6) ##特徵序列長度#middle
print(windowed_x.shape, windowed_y.shape)
# Out:
# (35646, 6, 10) (35646, 3)

# %%
x_train, y_train, x_test, y_test = split_data(windowed_x, windowed_y, 0.2)#數據集分割 #paper test為2016年, 大概20%?
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (28516, 6, 10) (28516, 3)
# (7130, 6, 10) (7130, 3)

# %%
model=Sequential()
model.add(LSTM(32, input_shape=(x_train.shape[1], x_train.shape[2]),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, input_shape=(x_train.shape[1],32),return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu',kernel_initializer='normal'))
model.add(Dense(3, activation='softmax', kernel_initializer='normal'))
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=150, validation_data=(x_test, y_test), batch_size=300, verbose=1)
# Out:
# Epoch 1/150
# 96/96 [==============================] - 4s 14ms/step - loss: 0.9564 - accuracy: 0.4585 - val_loss: 0.8939 - val_accuracy: 0.4495
# Epoch 2/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9104 - accuracy: 0.4657 - val_loss: 0.8953 - val_accuracy: 0.4495
# Epoch 3/150
# 96/96 [==============================] - 1s 9ms/step - loss: 0.9110 - accuracy: 0.4615 - val_loss: 0.8922 - val_accuracy: 0.4839
# Epoch 4/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9111 - accuracy: 0.4615 - val_loss: 0.8933 - val_accuracy: 0.4839
# Epoch 5/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9101 - accuracy: 0.4652 - val_loss: 0.8934 - val_accuracy: 0.4839
# Epoch 6/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9106 - accuracy: 0.4626 - val_loss: 0.8931 - val_accuracy: 0.4839
# Epoch 7/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9108 - accuracy: 0.4568 - val_loss: 0.8917 - val_accuracy: 0.4495
# Epoch 8/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9094 - accuracy: 0.4638 - val_loss: 0.8910 - val_accuracy: 0.4836
# Epoch 9/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9102 - accuracy: 0.4628 - val_loss: 0.8905 - val_accuracy: 0.4839
# Epoch 10/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9093 - accuracy: 0.4637 - val_loss: 0.8909 - val_accuracy: 0.4839
# Epoch 11/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9084 - accuracy: 0.4645 - val_loss: 0.8888 - val_accuracy: 0.4839
# Epoch 12/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9077 - accuracy: 0.4677 - val_loss: 0.8884 - val_accuracy: 0.4839
# Epoch 13/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9068 - accuracy: 0.4612 - val_loss: 0.8886 - val_accuracy: 0.4771
# Epoch 14/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9072 - accuracy: 0.4663 - val_loss: 0.8885 - val_accuracy: 0.4839
# Epoch 15/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9078 - accuracy: 0.4626 - val_loss: 0.8880 - val_accuracy: 0.4839
# Epoch 16/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9070 - accuracy: 0.4646 - val_loss: 0.8904 - val_accuracy: 0.4495
# Epoch 17/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9068 - accuracy: 0.4674 - val_loss: 0.8904 - val_accuracy: 0.4495
# Epoch 18/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9064 - accuracy: 0.4656 - val_loss: 0.8888 - val_accuracy: 0.4496
# Epoch 19/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9064 - accuracy: 0.4665 - val_loss: 0.8887 - val_accuracy: 0.4839
# Epoch 20/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9061 - accuracy: 0.4638 - val_loss: 0.8892 - val_accuracy: 0.4495
# Epoch 21/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9064 - accuracy: 0.4641 - val_loss: 0.8883 - val_accuracy: 0.4839
# Epoch 22/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9064 - accuracy: 0.4635 - val_loss: 0.8875 - val_accuracy: 0.4839
# Epoch 23/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9058 - accuracy: 0.4720 - val_loss: 0.8873 - val_accuracy: 0.4839
# Epoch 24/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9061 - accuracy: 0.4635 - val_loss: 0.8885 - val_accuracy: 0.4839
# Epoch 25/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9061 - accuracy: 0.4642 - val_loss: 0.8876 - val_accuracy: 0.4839
# Epoch 26/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9060 - accuracy: 0.4664 - val_loss: 0.8873 - val_accuracy: 0.4839
# Epoch 27/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9058 - accuracy: 0.4653 - val_loss: 0.8880 - val_accuracy: 0.4882
# Epoch 28/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9060 - accuracy: 0.4652 - val_loss: 0.8878 - val_accuracy: 0.4760
# Epoch 29/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9051 - accuracy: 0.4678 - val_loss: 0.8872 - val_accuracy: 0.4842
# Epoch 30/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9056 - accuracy: 0.4668 - val_loss: 0.8903 - val_accuracy: 0.4839
# Epoch 31/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9057 - accuracy: 0.4695 - val_loss: 0.8896 - val_accuracy: 0.4951
# Epoch 32/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9055 - accuracy: 0.4656 - val_loss: 0.8876 - val_accuracy: 0.4840
# Epoch 33/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9055 - accuracy: 0.4695 - val_loss: 0.8871 - val_accuracy: 0.4868
# Epoch 34/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9054 - accuracy: 0.4713 - val_loss: 0.8879 - val_accuracy: 0.4635
# Epoch 35/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9058 - accuracy: 0.4699 - val_loss: 0.8873 - val_accuracy: 0.4836
# Epoch 36/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9049 - accuracy: 0.4772 - val_loss: 0.8872 - val_accuracy: 0.4849
# Epoch 37/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9048 - accuracy: 0.4724 - val_loss: 0.8862 - val_accuracy: 0.4902
# Epoch 38/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9044 - accuracy: 0.4720 - val_loss: 0.8861 - val_accuracy: 0.4999
# Epoch 39/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9044 - accuracy: 0.4769 - val_loss: 0.8884 - val_accuracy: 0.4532
# Epoch 40/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9046 - accuracy: 0.4732 - val_loss: 0.8857 - val_accuracy: 0.4968
# Epoch 41/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9041 - accuracy: 0.4821 - val_loss: 0.8860 - val_accuracy: 0.4952
# Epoch 42/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9041 - accuracy: 0.4807 - val_loss: 0.8857 - val_accuracy: 0.4961
# Epoch 43/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9039 - accuracy: 0.4812 - val_loss: 0.8863 - val_accuracy: 0.4955
# Epoch 44/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9034 - accuracy: 0.4788 - val_loss: 0.8868 - val_accuracy: 0.4958
# Epoch 45/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9039 - accuracy: 0.4815 - val_loss: 0.8865 - val_accuracy: 0.4919
# Epoch 46/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9037 - accuracy: 0.4832 - val_loss: 0.8850 - val_accuracy: 0.4950
# Epoch 47/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9029 - accuracy: 0.4853 - val_loss: 0.8856 - val_accuracy: 0.4955
# Epoch 48/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9035 - accuracy: 0.4847 - val_loss: 0.8857 - val_accuracy: 0.4951
# Epoch 49/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9027 - accuracy: 0.4859 - val_loss: 0.8848 - val_accuracy: 0.4947
# Epoch 50/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9030 - accuracy: 0.4857 - val_loss: 0.8852 - val_accuracy: 0.4933
# Epoch 51/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9039 - accuracy: 0.4871 - val_loss: 0.8849 - val_accuracy: 0.4917
# Epoch 52/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9035 - accuracy: 0.4812 - val_loss: 0.8850 - val_accuracy: 0.4924
# Epoch 53/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9029 - accuracy: 0.4854 - val_loss: 0.8850 - val_accuracy: 0.4948
# Epoch 54/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9026 - accuracy: 0.4880 - val_loss: 0.8851 - val_accuracy: 0.4985
# Epoch 55/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9020 - accuracy: 0.4889 - val_loss: 0.8846 - val_accuracy: 0.4909
# Epoch 56/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9024 - accuracy: 0.4886 - val_loss: 0.8856 - val_accuracy: 0.4951
# Epoch 57/150
# 96/96 [==============================] - 1s 9ms/step - loss: 0.9025 - accuracy: 0.4844 - val_loss: 0.8891 - val_accuracy: 0.4942
# Epoch 58/150
# 96/96 [==============================] - 1s 9ms/step - loss: 0.9026 - accuracy: 0.4915 - val_loss: 0.8857 - val_accuracy: 0.4930
# Epoch 59/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9027 - accuracy: 0.4877 - val_loss: 0.8855 - val_accuracy: 0.4965
# Epoch 60/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9027 - accuracy: 0.4876 - val_loss: 0.8859 - val_accuracy: 0.4926
# Epoch 61/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9025 - accuracy: 0.4866 - val_loss: 0.8847 - val_accuracy: 0.4976
# Epoch 62/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9019 - accuracy: 0.4896 - val_loss: 0.8864 - val_accuracy: 0.4871
# Epoch 63/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9020 - accuracy: 0.4900 - val_loss: 0.8873 - val_accuracy: 0.4903
# Epoch 64/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9023 - accuracy: 0.4874 - val_loss: 0.8864 - val_accuracy: 0.4944
# Epoch 65/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9017 - accuracy: 0.4911 - val_loss: 0.8865 - val_accuracy: 0.4889
# Epoch 66/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9024 - accuracy: 0.4913 - val_loss: 0.8852 - val_accuracy: 0.4940
# Epoch 67/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9018 - accuracy: 0.4886 - val_loss: 0.8868 - val_accuracy: 0.4892
# Epoch 68/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9019 - accuracy: 0.4904 - val_loss: 0.8847 - val_accuracy: 0.4951
# Epoch 69/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9018 - accuracy: 0.4881 - val_loss: 0.8851 - val_accuracy: 0.4952
# Epoch 70/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9021 - accuracy: 0.4865 - val_loss: 0.8851 - val_accuracy: 0.4964
# Epoch 71/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9024 - accuracy: 0.4913 - val_loss: 0.8848 - val_accuracy: 0.4933
# Epoch 72/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9017 - accuracy: 0.4907 - val_loss: 0.8897 - val_accuracy: 0.4829
# Epoch 73/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9019 - accuracy: 0.4895 - val_loss: 0.8872 - val_accuracy: 0.4914
# Epoch 74/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9018 - accuracy: 0.4908 - val_loss: 0.8850 - val_accuracy: 0.4934
# Epoch 75/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9019 - accuracy: 0.4909 - val_loss: 0.8852 - val_accuracy: 0.4933
# Epoch 76/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9017 - accuracy: 0.4872 - val_loss: 0.8854 - val_accuracy: 0.4934
# Epoch 77/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9013 - accuracy: 0.4915 - val_loss: 0.8852 - val_accuracy: 0.4955
# Epoch 78/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9019 - accuracy: 0.4934 - val_loss: 0.8856 - val_accuracy: 0.4891
# Epoch 79/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9013 - accuracy: 0.4928 - val_loss: 0.8865 - val_accuracy: 0.4896
# Epoch 80/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9016 - accuracy: 0.4861 - val_loss: 0.8873 - val_accuracy: 0.4921
# Epoch 81/150
# 96/96 [==============================] - 1s 9ms/step - loss: 0.9013 - accuracy: 0.4941 - val_loss: 0.8874 - val_accuracy: 0.4899
# Epoch 82/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9021 - accuracy: 0.4912 - val_loss: 0.8851 - val_accuracy: 0.4942
# Epoch 83/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9009 - accuracy: 0.4924 - val_loss: 0.8867 - val_accuracy: 0.4893
# Epoch 84/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9010 - accuracy: 0.4915 - val_loss: 0.8861 - val_accuracy: 0.4886
# Epoch 85/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9018 - accuracy: 0.4874 - val_loss: 0.8854 - val_accuracy: 0.4928
# Epoch 86/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9013 - accuracy: 0.4947 - val_loss: 0.8870 - val_accuracy: 0.4893
# Epoch 87/150
# 96/96 [==============================] - 1s 9ms/step - loss: 0.9015 - accuracy: 0.4896 - val_loss: 0.8850 - val_accuracy: 0.4902
# Epoch 88/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9011 - accuracy: 0.4913 - val_loss: 0.8849 - val_accuracy: 0.4923
# Epoch 89/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9010 - accuracy: 0.4930 - val_loss: 0.8854 - val_accuracy: 0.4948
# Epoch 90/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9014 - accuracy: 0.4905 - val_loss: 0.8849 - val_accuracy: 0.4934
# Epoch 91/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9006 - accuracy: 0.4907 - val_loss: 0.8858 - val_accuracy: 0.4944
# Epoch 92/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9009 - accuracy: 0.4915 - val_loss: 0.8869 - val_accuracy: 0.4899
# Epoch 93/150
# 96/96 [==============================] - 1s 9ms/step - loss: 0.9014 - accuracy: 0.4891 - val_loss: 0.8848 - val_accuracy: 0.4926
# Epoch 94/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9006 - accuracy: 0.4955 - val_loss: 0.8871 - val_accuracy: 0.4851
# Epoch 95/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9009 - accuracy: 0.4899 - val_loss: 0.8853 - val_accuracy: 0.4931
# Epoch 96/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9008 - accuracy: 0.4914 - val_loss: 0.8862 - val_accuracy: 0.4896
# Epoch 97/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9003 - accuracy: 0.4949 - val_loss: 0.8850 - val_accuracy: 0.4916
# Epoch 98/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9003 - accuracy: 0.4944 - val_loss: 0.8856 - val_accuracy: 0.4945
# Epoch 99/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9005 - accuracy: 0.4930 - val_loss: 0.8853 - val_accuracy: 0.4892
# Epoch 100/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9015 - accuracy: 0.4915 - val_loss: 0.8869 - val_accuracy: 0.4913
# Epoch 101/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9008 - accuracy: 0.4901 - val_loss: 0.8868 - val_accuracy: 0.4928
# Epoch 102/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9006 - accuracy: 0.4939 - val_loss: 0.8891 - val_accuracy: 0.4829
# Epoch 103/150
# 96/96 [==============================] - 1s 9ms/step - loss: 0.9002 - accuracy: 0.4918 - val_loss: 0.8860 - val_accuracy: 0.4924
# Epoch 104/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9000 - accuracy: 0.4943 - val_loss: 0.8857 - val_accuracy: 0.4912
# Epoch 105/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8994 - accuracy: 0.4954 - val_loss: 0.8856 - val_accuracy: 0.4928
# Epoch 106/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8998 - accuracy: 0.4926 - val_loss: 0.8859 - val_accuracy: 0.4919
# Epoch 107/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9003 - accuracy: 0.4934 - val_loss: 0.8860 - val_accuracy: 0.4924
# Epoch 108/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9005 - accuracy: 0.4883 - val_loss: 0.8862 - val_accuracy: 0.4910
# Epoch 109/150
# 96/96 [==============================] - 1s 9ms/step - loss: 0.9002 - accuracy: 0.4913 - val_loss: 0.8863 - val_accuracy: 0.4891
# Epoch 110/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8999 - accuracy: 0.4926 - val_loss: 0.8857 - val_accuracy: 0.4909
# Epoch 111/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9002 - accuracy: 0.4953 - val_loss: 0.8859 - val_accuracy: 0.4903
# Epoch 112/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8996 - accuracy: 0.4960 - val_loss: 0.8857 - val_accuracy: 0.4944
# Epoch 113/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8994 - accuracy: 0.4928 - val_loss: 0.8867 - val_accuracy: 0.4905
# Epoch 114/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.9003 - accuracy: 0.4914 - val_loss: 0.8852 - val_accuracy: 0.4916
# Epoch 115/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8999 - accuracy: 0.4901 - val_loss: 0.8861 - val_accuracy: 0.4923
# Epoch 116/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8999 - accuracy: 0.4939 - val_loss: 0.8857 - val_accuracy: 0.4950
# Epoch 117/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8990 - accuracy: 0.4959 - val_loss: 0.8869 - val_accuracy: 0.4910
# Epoch 118/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8996 - accuracy: 0.4919 - val_loss: 0.8862 - val_accuracy: 0.4928
# Epoch 119/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8995 - accuracy: 0.4914 - val_loss: 0.8856 - val_accuracy: 0.4909
# Epoch 120/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8991 - accuracy: 0.4938 - val_loss: 0.8861 - val_accuracy: 0.4945
# Epoch 121/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8993 - accuracy: 0.4948 - val_loss: 0.8870 - val_accuracy: 0.4964
# Epoch 122/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8992 - accuracy: 0.4945 - val_loss: 0.8851 - val_accuracy: 0.4923
# Epoch 123/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8993 - accuracy: 0.4940 - val_loss: 0.8864 - val_accuracy: 0.4937
# Epoch 124/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8989 - accuracy: 0.4969 - val_loss: 0.8868 - val_accuracy: 0.4944
# Epoch 125/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8988 - accuracy: 0.4948 - val_loss: 0.8854 - val_accuracy: 0.4907
# Epoch 126/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8990 - accuracy: 0.4935 - val_loss: 0.8855 - val_accuracy: 0.4935
# Epoch 127/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8984 - accuracy: 0.4976 - val_loss: 0.8860 - val_accuracy: 0.4930
# Epoch 128/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8987 - accuracy: 0.4962 - val_loss: 0.8867 - val_accuracy: 0.4938
# Epoch 129/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8988 - accuracy: 0.4948 - val_loss: 0.8852 - val_accuracy: 0.4935
# Epoch 130/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8991 - accuracy: 0.4905 - val_loss: 0.8857 - val_accuracy: 0.4930
# Epoch 131/150
# 96/96 [==============================] - 1s 9ms/step - loss: 0.8989 - accuracy: 0.4943 - val_loss: 0.8871 - val_accuracy: 0.4920
# Epoch 132/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8986 - accuracy: 0.4972 - val_loss: 0.8866 - val_accuracy: 0.4973
# Epoch 133/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8990 - accuracy: 0.4950 - val_loss: 0.8865 - val_accuracy: 0.4921
# Epoch 134/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8988 - accuracy: 0.4972 - val_loss: 0.8861 - val_accuracy: 0.4954
# Epoch 135/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8983 - accuracy: 0.4982 - val_loss: 0.8863 - val_accuracy: 0.4961
# Epoch 136/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8981 - accuracy: 0.4964 - val_loss: 0.8856 - val_accuracy: 0.4961
# Epoch 137/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8986 - accuracy: 0.4952 - val_loss: 0.8859 - val_accuracy: 0.4941
# Epoch 138/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8978 - accuracy: 0.4982 - val_loss: 0.8856 - val_accuracy: 0.4961
# Epoch 139/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8983 - accuracy: 0.4954 - val_loss: 0.8877 - val_accuracy: 0.4903
# Epoch 140/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8979 - accuracy: 0.4962 - val_loss: 0.8872 - val_accuracy: 0.4884
# Epoch 141/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8983 - accuracy: 0.4960 - val_loss: 0.8851 - val_accuracy: 0.4942
# Epoch 142/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8981 - accuracy: 0.4980 - val_loss: 0.8865 - val_accuracy: 0.4952
# Epoch 143/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8979 - accuracy: 0.4978 - val_loss: 0.8864 - val_accuracy: 0.4976
# Epoch 144/150
# 96/96 [==============================] - 1s 9ms/step - loss: 0.8975 - accuracy: 0.4975 - val_loss: 0.8865 - val_accuracy: 0.4972
# Epoch 145/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8977 - accuracy: 0.5005 - val_loss: 0.8861 - val_accuracy: 0.4954
# Epoch 146/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8973 - accuracy: 0.4965 - val_loss: 0.8862 - val_accuracy: 0.4975
# Epoch 147/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8975 - accuracy: 0.4984 - val_loss: 0.8877 - val_accuracy: 0.4881
# Epoch 148/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8969 - accuracy: 0.4995 - val_loss: 0.8871 - val_accuracy: 0.4969
# Epoch 149/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8966 - accuracy: 0.4996 - val_loss: 0.8860 - val_accuracy: 0.4957
# Epoch 150/150
# 96/96 [==============================] - 1s 8ms/step - loss: 0.8974 - accuracy: 0.4962 - val_loss: 0.8863 - val_accuracy: 0.5001

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 6, 32)             5504
#
#  dropout_4 (Dropout)         (None, 6, 32)             0
#
#  lstm_5 (LSTM)               (None, 32)                8320
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_5 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 14979 (58.51 KB)
# Trainable params: 14979 (58.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
train_predict=model.predict(x_train)
test_predict=model.predict(x_test)
# Out:
# 892/892 [==============================] - 2s 1ms/step
# 223/223 [==============================] - 0s 1ms/step

# %%
# print(train_predict.shape)
# tr_predict=np.zeros((train_predict.shape[0], 8))
# te_predict=np.zeros((test_predict.shape[0], 8))

# tr_predict[:,5]=train_predict.squeeze()
# te_predict[:,5]=test_predict.squeeze()
# print(tr_predict[0])
# print(tr_predict.shape,te_predict.shape)

# tr_predict=scaler.inverse_transform(tr_predict)
# tr_predict=[x[5] for x in tr_predict]


# te_predict=scaler.inverse_transform(te_predict)
# te_predict=[x[5] for x in te_predict]
# # print(te_predict)

# print(tr_predict[:5])
# print(te_predict[:5])

# %%
# def custom_accuracy(array1, array2):
#     total_elements = len(array1)
#     correct_matches = 0

#     for val1, val2 in zip(array1, array2):
#         if (val1 > 0 and val2 > 0) or (val1 < 0 and val2 < 0):
#             correct_matches += 1
#         elif val1 == 0 and val2 == 0:
#             correct_matches += 1

#     accuracy = correct_matches / total_elements
#     return accuracy

# # for i in tr_predict:
# #     if i <=0 :
# #         print('y')
# yT=np.zeros((y_train.shape[0], 8))
# yT[:,5]=y_train.squeeze()
# yT=scaler.inverse_transform(yT)
# yT=[x[5] for x in yT]

# yt=np.zeros((y_test.shape[0], 8))
# yt[:,5]=y_test.squeeze()
# yt=scaler.inverse_transform(yt)
# yt=[x[5] for x in yt]

# print(custom_accuracy(tr_predict,yT))
# print(custom_accuracy(te_predict,yt))
# print(tr_predict[:5], y_train[:5])

# %%
    
test_predict_argmax = np.argmax(test_predict, axis=1)
# 将真实标签转换为真实的类别索引
y_test_argmax = np.argmax(y_test, axis=1)
# 计算准确率
accuracy = np.mean(y_test_argmax == test_predict_argmax)
print("Accuracy test:", accuracy)

np.save('10_test.npy', test_predict_argmax)

train_predict_argmax = np.argmax(train_predict, axis=1)
# 将真实标签转换为真实的类别索引
y_train_argmax = np.argmax(y_train, axis=1)
# 计算准确率
accuracy = np.mean(y_train_argmax == train_predict_argmax)
print("Accuracy train:", accuracy)

np.save('10_train.npy', train_predict_argmax)


idx_l=[]
for idx, value in enumerate(test_predict_argmax):
    if value == 0:
        idx_l.append(idx)

# print(idx_l)
idx_ll=[]
for idx, value in enumerate(y_test_argmax):
    if value == 0:
        idx_ll.append(idx)

print(len(idx_l),len(idx_ll))

##drop 0.2 兩次 step=6 RSI 8:30~10:30
# Accuracy test: 0.4788966691167937
# Accuracy train: 0.47840300210843956
#全時段
# Accuracy test: 0.4549774716169764
# Accuracy train: 0.45354446631858253
# Out:
# Accuracy test: 0.500140252454418
# Accuracy train: 0.49852714265675413
# 0 475

# %%
print(history.history.keys())
plt.rcParams['font.sans-serif'] = ['SimHei', 'Arial']  # 可以指定多个字体备选
plt.rcParams['axes.unicode_minus'] = False  # 用于解决负号显示问题
# plot history
plt.figure(figsize=(7, 4))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# plot history
plt.figure(figsize=(7, 4))
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
