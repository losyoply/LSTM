# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch.nn as nn
import csv
import pandas as pd
from keras.callbacks import History
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout,Input
# import tensorflow as tf
# print(tf.__file__)
from pandas import read_csv
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["axes.unicode_minus"]=False

# %%
def generate_diff(input_array):
    output_array = [0]  # 初始值设为0
    
    for i in range(1, len(input_array)):
        output_array.append(input_array[i] - input_array[i - 1])
        
    return output_array
    
# load data
def parse(x):
    return datetime.strptime(x, '%Y/%m/%d')

dataset = read_csv('2012-2016.csv')
dataset['DateTime'] = pd.to_datetime(dataset['Date'] + ' ' + dataset['Time'])



# # 将 Time 列转换为时间格式
# dataset['Time'] = pd.to_datetime(dataset['Time'])

# # 指定时间范围
# start_time = pd.to_datetime("8:44:00").time()
# end_time = pd.to_datetime("10:30:10").time()

# 选择指定时间范围内的数据
# selected_data = dataset[(dataset['Time'].dt.time >= start_time) & (dataset['Time'].dt.time <= end_time)]
selected_data=dataset


###### 新的一天，将diff设置为0
#selected_data.loc[dataset['Date'] != dataset['Date'].shift(), ['Diff','Diff_Pct']] = 0

#######
selected_data.set_index('DateTime', inplace=True)
selected_data.drop(columns=['Time','Date'], inplace=True)

selected_data=selected_data.dropna()
# summarize first 5 rows
# print(selected_data.head(5))

df_resampled = selected_data.resample('10T').agg({
    'Open': 'first',
    'High': 'max',
    'Low': 'min',
    'Close': 'last',
    'TotalVolume': 'sum',
})
df_resampled['Diff_Pct'] = df_resampled['Close'].pct_change()
df_resampled['Diff'] = df_resampled['Close'].diff()
df_resampled["C-L"] = df_resampled["Close"] - df_resampled["Low"]
df_resampled["H-L"] = df_resampled["High"] - df_resampled["Low"]
df_resampled["%K"] = (df_resampled["C-L"] / df_resampled["H-L"]) * 100
# 计算%D指标，这里采用3周期的简单移动平均
df_resampled["%D"] = df_resampled["%K"].rolling(window=3).mean()

# RSI
df_resampled['Gain'] = df_resampled['Diff'].apply(lambda x: x if x > 0 else 0)
df_resampled['Loss'] = df_resampled['Diff'].apply(lambda x: -x if x < 0 else 0)

# 计算平均的上涨和下跌价格变化（使用14天的时间窗口）
window = 14
df_resampled['AvgGain'] = df_resampled['Gain'].rolling(window=window).mean()
df_resampled['AvgLoss'] = df_resampled['Loss'].rolling(window=window).mean()
# 计算相对强度（RS）
df_resampled['RS'] = df_resampled['AvgGain'] / df_resampled['AvgLoss']
# 计算RSI
df_resampled['RSI'] = 100 - (100 / (1 + df_resampled['RS']))
df_resampled.drop(columns=['RS','AvgLoss','AvgGain','Gain', 'Loss'], inplace=True)

############
# 計算中間通道（中線），假設使用20期的簡單移動平均
df_resampled['SMA'] = df_resampled['Close'].rolling(window=20).mean()

# 計算標準差，假設使用20期的標準差
df_resampled['StdDev'] = df_resampled['Close'].rolling(window=20).std()

# 計算上通道（上軌）
df_resampled['UpperBand'] = df_resampled['SMA'] + (2 * df_resampled['StdDev'])

# 計算下通道（下軌）
df_resampled['LowerBand'] = df_resampled['SMA'] - (2 * df_resampled['StdDev'])

# 現在你的數據集中有了布林通道的相關特徵，你可以將它們用於預測
###########

# 如果你想要去掉NaN值，可以使用以下代碼
df_resampled = df_resampled.dropna()
print(df_resampled[:6])


# # save to file
# Out:
#                        Open    High     Low   Close  TotalVolume  Diff_Pct  \
# DateTime
# 2012-01-02 11:50:00  6947.0  6959.0  6946.0  6956.0         1238  0.001296
# 2012-01-02 12:00:00  6958.0  6962.0  6956.0  6956.0         1162  0.000000
# 2012-01-02 12:10:00  6956.0  6959.0  6951.0  6956.0         1150  0.000000
# 2012-01-02 12:20:00  6956.0  6960.0  6954.0  6955.0          597 -0.000144
# 2012-01-02 12:30:00  6955.0  6972.0  6955.0  6964.0         2408  0.001294
# 2012-01-02 12:40:00  6965.0  6968.0  6950.0  6955.0         1917 -0.001292
#
#                      Diff   C-L   H-L         %K         %D        RSI  \
# DateTime
# 2012-01-02 11:50:00   9.0  10.0  13.0  76.923077  52.307692  14.432990
# 2012-01-02 12:00:00   0.0   0.0   6.0   0.000000  30.085470  11.702128
# 2012-01-02 12:10:00   0.0   5.0   8.0  62.500000  46.474359  12.643678
# 2012-01-02 12:20:00  -1.0   1.0   6.0  16.666667  26.388889  11.494253
# 2012-01-02 12:30:00   9.0   9.0  17.0  52.941176  44.035948  20.430108
# 2012-01-02 12:40:00  -9.0   5.0  18.0  27.777778  32.461874  25.333333
#
#                          SMA     StdDev    UpperBand    LowerBand
# DateTime
# 2012-01-02 11:50:00  6997.95  32.449921  7062.849842  6933.050158
# 2012-01-02 12:00:00  6995.00  33.483696  7061.967392  6928.032608
# 2012-01-02 12:10:00  6990.75  32.723523  7056.197046  6925.302954
# 2012-01-02 12:20:00  6986.35  31.209437  7048.768874  6923.931126
# 2012-01-02 12:30:00  6983.20  30.048382  7043.296764  6923.103236
# 2012-01-02 12:40:00  6979.55  28.724600  7036.999200  6922.100800

# %%
# sns.set_style("darkgrid")
# plt.figure(figsize=(15,9))
# plt.plot(selected_data.index,selected_data[['Close']])
# # plt.xticks(range(0,dataset.shape[0], 10000), dataset.index[::10000],rotation=45)
# plt.title("price", fontsize=18, fontweight='bold')
# plt.xlabel("date", fontsize=18)
# plt.ylabel("close", fontsize=18)
# plt.show()

# plt.figure(figsize=(16,4))
# plt.plot(selected_data['LogDiff'])

# %%
def generate_y_for10(input_array):
    output_array = [] 
    
    for i in range(0, len(input_array)):
        if input_array[i]>0:
            output_array.append(2)
        elif input_array[i]<0:
            output_array.append(1)
        else:
            output_array.append(0)
    
    return output_array

def generate_y(input_array):
    output_array = []  # 初始值设为0
    
    for i in range(0, len(input_array)-1):
        output_array.append(input_array[i+1] - input_array[i])
        
    return output_array
    

values = df_resampled.values
# ensure all data is float
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0,1))
#############################################
# scaler_diff=MinMaxScaler(feature_range=(-1,1))
# t=scaler_diff.fit_transform(values[:,-1].reshape(-1,1))
# print(t)
#############################################
# normalize features
scaled = scaler.fit_transform(values)#待檢查
print(scaled)

# ##漲跌平
class_indices= generate_y_for10(values[:,5]) #diff
# 确定类别的数量
num_classes = max(class_indices) + 1

# 使用NumPy创建一个全零数组，形状为(数组长度, 类别数量)
y_label = np.zeros((len(class_indices), num_classes))
# 将对应的位置设置为1
y_label[np.arange(len(class_indices)), class_indices] = 1
# y_label=generate_y(values[:,3])#close明天相對今天增長量
print(y_label[:5])
# ##

# # 新增一列(diff 正規過後)
# # diff_n= np.array(generate_diff(scaled[:,3]))#close
# diff_n=
# # 创建布尔掩码
# mask = values[:,5] == 0.0
# # 使用布尔掩码将 b 中对应位置的值设为 0
# diff_n[mask] = 0.0
# x_label=np.hstack((scaled[:,[0,1,2,3,4,6,7]], diff_n.reshape(-1, 1)))
###########################
x_label=scaled[:,[0,1,2,3,5,7,8,9,10,11]]
# print(scaled[:5])
print(x_label[208:215])
# Out:
# [[0.03487277 0.03496075 0.03581524 ... 0.17494844 0.06160522 0.04616737]
#  [0.03832865 0.0359056  0.03895712 ... 0.18072946 0.0613277  0.04460788]
#  [0.03770041 0.03496075 0.03738618 ... 0.17647846 0.0595119  0.04375935]
#  ...
#  [0.7618599  0.7622049  0.76280236 ... 0.04131111 0.75685835 0.762584  ]
#  [0.76280236 0.761575   0.76280236 ... 0.03378462 0.7564206  0.76382446]
#  [0.7621741  0.7609451  0.76280236 ... 0.03023331 0.75631976 0.7645147 ]]
# [[0. 0. 1.]
#  [1. 0. 0.]
#  [1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# [[0.2507069  0.25007892 0.25164938 0.2531407  0.5558203  0.08510638
#   0.07079646 0.88888884 0.45502648 0.5391997 ]
#  [0.25322032 0.25039387 0.24913621 0.24874377 0.43380296 0.0212766
#   0.15044248 0.1111111  0.38095236 0.5174877 ]
#  [0.24850774 0.24692917 0.2478795  0.24905777 0.5169751  0.07446808
#   0.08849557 0.6363636  0.54545456 0.59478414]
#  [0.24850774 0.24944901 0.24976444 0.25251245 0.5725101  0.12765957
#   0.10619469 0.9230769  0.55685055 0.6009281 ]
#  [0.25196362 0.25228357 0.25227785 0.2534547  0.5280575  0.07446808
#   0.11504425 0.5        0.68648016 0.6009281 ]
#  [0.25322032 0.25259852 0.25322032 0.2534547  0.5114208  0.04255319
#   0.09734513 0.3333333  0.5854701  0.5752179 ]
#  [0.25322032 0.25133872 0.25353456 0.2534547  0.5114208  0.03191489
#   0.05309734 0.42857143 0.4206349  0.5301161 ]]

# %%
# values = selected_data.values
# # ensure all data is float
# values = values.astype('float32')
# scaler = MinMaxScaler(feature_range=(0,1)).fit(values)
# x_label=scaled=scaler.transform(values)
# print(x_label[:5])
# y_label=[x[5] for x in scaled]
# y_label = y_label[1:]
# print(y_label[:5])
# print(y_label[0])

# qq=np.zeros((len(y_label),8))
# qq[:,5]=np.array(y_label)
# print(qq)
# qqq=scaler.inverse_transform(qq)
# print(qqq[0,5])

# %%
def split_windows(data,label, seq_length):
    x=[]
    y=[]
    for i in range(len(data)-seq_length-1):
        _x=data[i:(i+seq_length),:]
        _y=label[i+seq_length]
        x.append(_x)
        y.append(_y)
    x,y=np.array(x),np.array(y)
    # print('x.shape,y.shape=\n',x.shape,y.shape)
    return x,y

def split_data(x, y, split_ratio):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=split_ratio, shuffle=False)
    return x_train, y_train, x_test, y_test

# %%
windowed_x, windowed_y = split_windows(x_label, y_label, 6) ##特徵序列長度#middle
print(windowed_x.shape, windowed_y.shape)
# Out:
# (14717, 6, 10) (14717, 3)

# %%
x_train, y_train, x_test, y_test = split_data(windowed_x, windowed_y, 0.2)#數據集分割 #paper test為2016年, 大概20%?
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (11773, 6, 10) (11773, 3)
# (2944, 6, 10) (2944, 3)

# %%
model=Sequential()
model.add(LSTM(32, input_shape=(x_train.shape[1], x_train.shape[2]),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, input_shape=(x_train.shape[1],32),return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu',kernel_initializer='normal'))
model.add(Dense(3, activation='softmax', kernel_initializer='normal'))
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=150, validation_data=(x_test, y_test), batch_size=300, verbose=1)
# Out:
# Epoch 1/150
# 40/40 [==============================] - 6s 40ms/step - loss: 1.0282 - accuracy: 0.4605 - val_loss: 0.9287 - val_accuracy: 0.4674
# Epoch 2/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9369 - accuracy: 0.4606 - val_loss: 0.9253 - val_accuracy: 0.4674
# Epoch 3/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9343 - accuracy: 0.4556 - val_loss: 0.9256 - val_accuracy: 0.4674
# Epoch 4/150
# 40/40 [==============================] - 1s 31ms/step - loss: 0.9352 - accuracy: 0.4548 - val_loss: 0.9253 - val_accuracy: 0.4674
# Epoch 5/150
# 40/40 [==============================] - 1s 12ms/step - loss: 0.9345 - accuracy: 0.4625 - val_loss: 0.9255 - val_accuracy: 0.4477
# Epoch 6/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9349 - accuracy: 0.4520 - val_loss: 0.9251 - val_accuracy: 0.4674
# Epoch 7/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9353 - accuracy: 0.4626 - val_loss: 0.9247 - val_accuracy: 0.4674
# Epoch 8/150
# 40/40 [==============================] - 0s 10ms/step - loss: 0.9349 - accuracy: 0.4597 - val_loss: 0.9248 - val_accuracy: 0.4674
# Epoch 9/150
# 40/40 [==============================] - 0s 10ms/step - loss: 0.9346 - accuracy: 0.4594 - val_loss: 0.9257 - val_accuracy: 0.4674
# Epoch 10/150
# 40/40 [==============================] - 1s 12ms/step - loss: 0.9350 - accuracy: 0.4594 - val_loss: 0.9246 - val_accuracy: 0.4674
# Epoch 11/150
# 40/40 [==============================] - 1s 27ms/step - loss: 0.9343 - accuracy: 0.4560 - val_loss: 0.9245 - val_accuracy: 0.4674
# Epoch 12/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9342 - accuracy: 0.4635 - val_loss: 0.9248 - val_accuracy: 0.4477
# Epoch 13/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9335 - accuracy: 0.4597 - val_loss: 0.9241 - val_accuracy: 0.4674
# Epoch 14/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9330 - accuracy: 0.4583 - val_loss: 0.9265 - val_accuracy: 0.4674
# Epoch 15/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9337 - accuracy: 0.4610 - val_loss: 0.9252 - val_accuracy: 0.4688
# Epoch 16/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9335 - accuracy: 0.4498 - val_loss: 0.9246 - val_accuracy: 0.4674
# Epoch 17/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9343 - accuracy: 0.4554 - val_loss: 0.9241 - val_accuracy: 0.4688
# Epoch 18/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9334 - accuracy: 0.4639 - val_loss: 0.9240 - val_accuracy: 0.4674
# Epoch 19/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9330 - accuracy: 0.4633 - val_loss: 0.9245 - val_accuracy: 0.4674
# Epoch 20/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9346 - accuracy: 0.4560 - val_loss: 0.9271 - val_accuracy: 0.4674
# Epoch 21/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9320 - accuracy: 0.4595 - val_loss: 0.9236 - val_accuracy: 0.4674
# Epoch 22/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9322 - accuracy: 0.4532 - val_loss: 0.9247 - val_accuracy: 0.4674
# Epoch 23/150
# 40/40 [==============================] - 1s 12ms/step - loss: 0.9316 - accuracy: 0.4605 - val_loss: 0.9250 - val_accuracy: 0.4674
# Epoch 24/150
# 40/40 [==============================] - 1s 24ms/step - loss: 0.9321 - accuracy: 0.4561 - val_loss: 0.9239 - val_accuracy: 0.4674
# Epoch 25/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9325 - accuracy: 0.4591 - val_loss: 0.9250 - val_accuracy: 0.4674
# Epoch 26/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9333 - accuracy: 0.4559 - val_loss: 0.9251 - val_accuracy: 0.4674
# Epoch 27/150
# 40/40 [==============================] - 1s 12ms/step - loss: 0.9320 - accuracy: 0.4611 - val_loss: 0.9258 - val_accuracy: 0.4674
# Epoch 28/150
# 40/40 [==============================] - 1s 29ms/step - loss: 0.9313 - accuracy: 0.4602 - val_loss: 0.9251 - val_accuracy: 0.4698
# Epoch 29/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9318 - accuracy: 0.4608 - val_loss: 0.9259 - val_accuracy: 0.4708
# Epoch 30/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9324 - accuracy: 0.4596 - val_loss: 0.9247 - val_accuracy: 0.4623
# Epoch 31/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9311 - accuracy: 0.4558 - val_loss: 0.9250 - val_accuracy: 0.4674
# Epoch 32/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9317 - accuracy: 0.4618 - val_loss: 0.9255 - val_accuracy: 0.4674
# Epoch 33/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9320 - accuracy: 0.4592 - val_loss: 0.9241 - val_accuracy: 0.4674
# Epoch 34/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9308 - accuracy: 0.4615 - val_loss: 0.9247 - val_accuracy: 0.4674
# Epoch 35/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9315 - accuracy: 0.4616 - val_loss: 0.9239 - val_accuracy: 0.4674
# Epoch 36/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9303 - accuracy: 0.4560 - val_loss: 0.9256 - val_accuracy: 0.4674
# Epoch 37/150
# 40/40 [==============================] - 0s 10ms/step - loss: 0.9308 - accuracy: 0.4569 - val_loss: 0.9250 - val_accuracy: 0.4674
# Epoch 38/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9305 - accuracy: 0.4644 - val_loss: 0.9272 - val_accuracy: 0.4674
# Epoch 39/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9317 - accuracy: 0.4607 - val_loss: 0.9251 - val_accuracy: 0.4674
# Epoch 40/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9318 - accuracy: 0.4571 - val_loss: 0.9265 - val_accuracy: 0.4674
# Epoch 41/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9313 - accuracy: 0.4583 - val_loss: 0.9243 - val_accuracy: 0.4691
# Epoch 42/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9309 - accuracy: 0.4617 - val_loss: 0.9244 - val_accuracy: 0.4674
# Epoch 43/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9312 - accuracy: 0.4548 - val_loss: 0.9265 - val_accuracy: 0.4640
# Epoch 44/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9308 - accuracy: 0.4602 - val_loss: 0.9242 - val_accuracy: 0.4674
# Epoch 45/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9303 - accuracy: 0.4581 - val_loss: 0.9280 - val_accuracy: 0.4674
# Epoch 46/150
# 40/40 [==============================] - 1s 16ms/step - loss: 0.9314 - accuracy: 0.4519 - val_loss: 0.9243 - val_accuracy: 0.4674
# Epoch 47/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9308 - accuracy: 0.4576 - val_loss: 0.9254 - val_accuracy: 0.4674
# Epoch 48/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9305 - accuracy: 0.4632 - val_loss: 0.9264 - val_accuracy: 0.4565
# Epoch 49/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9304 - accuracy: 0.4668 - val_loss: 0.9256 - val_accuracy: 0.4674
# Epoch 50/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9298 - accuracy: 0.4600 - val_loss: 0.9275 - val_accuracy: 0.4674
# Epoch 51/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9301 - accuracy: 0.4596 - val_loss: 0.9244 - val_accuracy: 0.4674
# Epoch 52/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9306 - accuracy: 0.4622 - val_loss: 0.9246 - val_accuracy: 0.4684
# Epoch 53/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9314 - accuracy: 0.4571 - val_loss: 0.9249 - val_accuracy: 0.4674
# Epoch 54/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9315 - accuracy: 0.4571 - val_loss: 0.9246 - val_accuracy: 0.4616
# Epoch 55/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9310 - accuracy: 0.4599 - val_loss: 0.9242 - val_accuracy: 0.4674
# Epoch 56/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9305 - accuracy: 0.4617 - val_loss: 0.9261 - val_accuracy: 0.4674
# Epoch 57/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9306 - accuracy: 0.4617 - val_loss: 0.9291 - val_accuracy: 0.4657
# Epoch 58/150
# 40/40 [==============================] - 1s 14ms/step - loss: 0.9307 - accuracy: 0.4568 - val_loss: 0.9249 - val_accuracy: 0.4708
# Epoch 59/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9299 - accuracy: 0.4628 - val_loss: 0.9273 - val_accuracy: 0.4674
# Epoch 60/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9300 - accuracy: 0.4622 - val_loss: 0.9322 - val_accuracy: 0.4677
# Epoch 61/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9305 - accuracy: 0.4562 - val_loss: 0.9280 - val_accuracy: 0.4531
# Epoch 62/150
# 40/40 [==============================] - 1s 27ms/step - loss: 0.9301 - accuracy: 0.4571 - val_loss: 0.9271 - val_accuracy: 0.4606
# Epoch 63/150
# 40/40 [==============================] - 1s 21ms/step - loss: 0.9296 - accuracy: 0.4616 - val_loss: 0.9266 - val_accuracy: 0.4650
# Epoch 64/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9304 - accuracy: 0.4547 - val_loss: 0.9264 - val_accuracy: 0.4674
# Epoch 65/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9295 - accuracy: 0.4631 - val_loss: 0.9250 - val_accuracy: 0.4691
# Epoch 66/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9296 - accuracy: 0.4632 - val_loss: 0.9265 - val_accuracy: 0.4487
# Epoch 67/150
# 40/40 [==============================] - 1s 29ms/step - loss: 0.9301 - accuracy: 0.4585 - val_loss: 0.9260 - val_accuracy: 0.4630
# Epoch 68/150
# 40/40 [==============================] - 1s 31ms/step - loss: 0.9299 - accuracy: 0.4661 - val_loss: 0.9257 - val_accuracy: 0.4518
# Epoch 69/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9303 - accuracy: 0.4600 - val_loss: 0.9255 - val_accuracy: 0.4694
# Epoch 70/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9297 - accuracy: 0.4593 - val_loss: 0.9282 - val_accuracy: 0.4691
# Epoch 71/150
# 40/40 [==============================] - 1s 30ms/step - loss: 0.9301 - accuracy: 0.4610 - val_loss: 0.9251 - val_accuracy: 0.4616
# Epoch 72/150
# 40/40 [==============================] - 1s 25ms/step - loss: 0.9297 - accuracy: 0.4627 - val_loss: 0.9249 - val_accuracy: 0.4667
# Epoch 73/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9296 - accuracy: 0.4623 - val_loss: 0.9255 - val_accuracy: 0.4674
# Epoch 74/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9299 - accuracy: 0.4611 - val_loss: 0.9252 - val_accuracy: 0.4732
# Epoch 75/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9300 - accuracy: 0.4638 - val_loss: 0.9259 - val_accuracy: 0.4691
# Epoch 76/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9302 - accuracy: 0.4594 - val_loss: 0.9264 - val_accuracy: 0.4674
# Epoch 77/150
# 40/40 [==============================] - 0s 13ms/step - loss: 0.9298 - accuracy: 0.4621 - val_loss: 0.9253 - val_accuracy: 0.4691
# Epoch 78/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9298 - accuracy: 0.4645 - val_loss: 0.9254 - val_accuracy: 0.4688
# Epoch 79/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9297 - accuracy: 0.4637 - val_loss: 0.9269 - val_accuracy: 0.4684
# Epoch 80/150
# 40/40 [==============================] - 1s 17ms/step - loss: 0.9294 - accuracy: 0.4620 - val_loss: 0.9256 - val_accuracy: 0.4684
# Epoch 81/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9292 - accuracy: 0.4549 - val_loss: 0.9254 - val_accuracy: 0.4691
# Epoch 82/150
# 40/40 [==============================] - 1s 12ms/step - loss: 0.9295 - accuracy: 0.4659 - val_loss: 0.9275 - val_accuracy: 0.4647
# Epoch 83/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9302 - accuracy: 0.4607 - val_loss: 0.9253 - val_accuracy: 0.4701
# Epoch 84/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9297 - accuracy: 0.4541 - val_loss: 0.9278 - val_accuracy: 0.4660
# Epoch 85/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9300 - accuracy: 0.4625 - val_loss: 0.9250 - val_accuracy: 0.4691
# Epoch 86/150
# 40/40 [==============================] - 1s 14ms/step - loss: 0.9296 - accuracy: 0.4623 - val_loss: 0.9252 - val_accuracy: 0.4677
# Epoch 87/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9298 - accuracy: 0.4664 - val_loss: 0.9284 - val_accuracy: 0.4650
# Epoch 88/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9291 - accuracy: 0.4625 - val_loss: 0.9267 - val_accuracy: 0.4667
# Epoch 89/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9291 - accuracy: 0.4683 - val_loss: 0.9257 - val_accuracy: 0.4688
# Epoch 90/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9292 - accuracy: 0.4655 - val_loss: 0.9294 - val_accuracy: 0.4664
# Epoch 91/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9297 - accuracy: 0.4690 - val_loss: 0.9291 - val_accuracy: 0.4721
# Epoch 92/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9293 - accuracy: 0.4692 - val_loss: 0.9285 - val_accuracy: 0.4701
# Epoch 93/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9291 - accuracy: 0.4689 - val_loss: 0.9267 - val_accuracy: 0.4684
# Epoch 94/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9295 - accuracy: 0.4597 - val_loss: 0.9260 - val_accuracy: 0.4725
# Epoch 95/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9291 - accuracy: 0.4656 - val_loss: 0.9258 - val_accuracy: 0.4545
# Epoch 96/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9295 - accuracy: 0.4567 - val_loss: 0.9257 - val_accuracy: 0.4660
# Epoch 97/150
# 40/40 [==============================] - 1s 14ms/step - loss: 0.9291 - accuracy: 0.4662 - val_loss: 0.9266 - val_accuracy: 0.4677
# Epoch 98/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9292 - accuracy: 0.4656 - val_loss: 0.9252 - val_accuracy: 0.4708
# Epoch 99/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9289 - accuracy: 0.4601 - val_loss: 0.9261 - val_accuracy: 0.4704
# Epoch 100/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9290 - accuracy: 0.4639 - val_loss: 0.9282 - val_accuracy: 0.4738
# Epoch 101/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9286 - accuracy: 0.4645 - val_loss: 0.9274 - val_accuracy: 0.4674
# Epoch 102/150
# 40/40 [==============================] - 1s 12ms/step - loss: 0.9289 - accuracy: 0.4560 - val_loss: 0.9261 - val_accuracy: 0.4715
# Epoch 103/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9287 - accuracy: 0.4695 - val_loss: 0.9255 - val_accuracy: 0.4674
# Epoch 104/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9289 - accuracy: 0.4624 - val_loss: 0.9268 - val_accuracy: 0.4674
# Epoch 105/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9281 - accuracy: 0.4679 - val_loss: 0.9260 - val_accuracy: 0.4749
# Epoch 106/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9291 - accuracy: 0.4656 - val_loss: 0.9256 - val_accuracy: 0.4772
# Epoch 107/150
# 40/40 [==============================] - 1s 21ms/step - loss: 0.9287 - accuracy: 0.4723 - val_loss: 0.9267 - val_accuracy: 0.4735
# Epoch 108/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9288 - accuracy: 0.4616 - val_loss: 0.9292 - val_accuracy: 0.4548
# Epoch 109/150
# 40/40 [==============================] - 1s 22ms/step - loss: 0.9284 - accuracy: 0.4681 - val_loss: 0.9276 - val_accuracy: 0.4745
# Epoch 110/150
# 40/40 [==============================] - 1s 29ms/step - loss: 0.9291 - accuracy: 0.4684 - val_loss: 0.9256 - val_accuracy: 0.4793
# Epoch 111/150
# 40/40 [==============================] - 1s 17ms/step - loss: 0.9281 - accuracy: 0.4649 - val_loss: 0.9250 - val_accuracy: 0.4755
# Epoch 112/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9283 - accuracy: 0.4694 - val_loss: 0.9257 - val_accuracy: 0.4698
# Epoch 113/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9284 - accuracy: 0.4656 - val_loss: 0.9256 - val_accuracy: 0.4701
# Epoch 114/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9277 - accuracy: 0.4658 - val_loss: 0.9256 - val_accuracy: 0.4769
# Epoch 115/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9281 - accuracy: 0.4695 - val_loss: 0.9264 - val_accuracy: 0.4701
# Epoch 116/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9282 - accuracy: 0.4664 - val_loss: 0.9255 - val_accuracy: 0.4715
# Epoch 117/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9282 - accuracy: 0.4764 - val_loss: 0.9261 - val_accuracy: 0.4674
# Epoch 118/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9280 - accuracy: 0.4706 - val_loss: 0.9275 - val_accuracy: 0.4684
# Epoch 119/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9279 - accuracy: 0.4719 - val_loss: 0.9262 - val_accuracy: 0.4603
# Epoch 120/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9281 - accuracy: 0.4645 - val_loss: 0.9277 - val_accuracy: 0.4524
# Epoch 121/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9289 - accuracy: 0.4708 - val_loss: 0.9252 - val_accuracy: 0.4684
# Epoch 122/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9277 - accuracy: 0.4718 - val_loss: 0.9279 - val_accuracy: 0.4650
# Epoch 123/150
# 40/40 [==============================] - 1s 15ms/step - loss: 0.9281 - accuracy: 0.4738 - val_loss: 0.9259 - val_accuracy: 0.4657
# Epoch 124/150
# 40/40 [==============================] - 1s 17ms/step - loss: 0.9276 - accuracy: 0.4731 - val_loss: 0.9260 - val_accuracy: 0.4776
# Epoch 125/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9283 - accuracy: 0.4739 - val_loss: 0.9257 - val_accuracy: 0.4745
# Epoch 126/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9275 - accuracy: 0.4729 - val_loss: 0.9261 - val_accuracy: 0.4694
# Epoch 127/150
# 40/40 [==============================] - 1s 24ms/step - loss: 0.9276 - accuracy: 0.4750 - val_loss: 0.9262 - val_accuracy: 0.4742
# Epoch 128/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9277 - accuracy: 0.4735 - val_loss: 0.9275 - val_accuracy: 0.4715
# Epoch 129/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9269 - accuracy: 0.4748 - val_loss: 0.9257 - val_accuracy: 0.4688
# Epoch 130/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9273 - accuracy: 0.4695 - val_loss: 0.9269 - val_accuracy: 0.4616
# Epoch 131/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9269 - accuracy: 0.4783 - val_loss: 0.9254 - val_accuracy: 0.4840
# Epoch 132/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9281 - accuracy: 0.4760 - val_loss: 0.9265 - val_accuracy: 0.4789
# Epoch 133/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9271 - accuracy: 0.4727 - val_loss: 0.9259 - val_accuracy: 0.4796
# Epoch 134/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9271 - accuracy: 0.4707 - val_loss: 0.9259 - val_accuracy: 0.4694
# Epoch 135/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9258 - accuracy: 0.4763 - val_loss: 0.9266 - val_accuracy: 0.4762
# Epoch 136/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9272 - accuracy: 0.4721 - val_loss: 0.9260 - val_accuracy: 0.4671
# Epoch 137/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9268 - accuracy: 0.4715 - val_loss: 0.9263 - val_accuracy: 0.4704
# Epoch 138/150
# 40/40 [==============================] - 1s 14ms/step - loss: 0.9269 - accuracy: 0.4754 - val_loss: 0.9262 - val_accuracy: 0.4732
# Epoch 139/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9267 - accuracy: 0.4717 - val_loss: 0.9281 - val_accuracy: 0.4647
# Epoch 140/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9263 - accuracy: 0.4741 - val_loss: 0.9264 - val_accuracy: 0.4715
# Epoch 141/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9270 - accuracy: 0.4772 - val_loss: 0.9270 - val_accuracy: 0.4620
# Epoch 142/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9269 - accuracy: 0.4724 - val_loss: 0.9260 - val_accuracy: 0.4806
# Epoch 143/150
# 40/40 [==============================] - 1s 13ms/step - loss: 0.9265 - accuracy: 0.4714 - val_loss: 0.9261 - val_accuracy: 0.4715
# Epoch 144/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9262 - accuracy: 0.4820 - val_loss: 0.9271 - val_accuracy: 0.4745
# Epoch 145/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9267 - accuracy: 0.4795 - val_loss: 0.9263 - val_accuracy: 0.4667
# Epoch 146/150
# 40/40 [==============================] - 0s 12ms/step - loss: 0.9260 - accuracy: 0.4751 - val_loss: 0.9291 - val_accuracy: 0.4647
# Epoch 147/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9258 - accuracy: 0.4780 - val_loss: 0.9272 - val_accuracy: 0.4732
# Epoch 148/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9262 - accuracy: 0.4819 - val_loss: 0.9267 - val_accuracy: 0.4766
# Epoch 149/150
# 40/40 [==============================] - 0s 11ms/step - loss: 0.9265 - accuracy: 0.4723 - val_loss: 0.9269 - val_accuracy: 0.4776
# Epoch 150/150
# 40/40 [==============================] - 0s 13ms/step - loss: 0.9254 - accuracy: 0.4774 - val_loss: 0.9279 - val_accuracy: 0.4698

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 6, 32)             5504
#
#  dropout (Dropout)           (None, 6, 32)             0
#
#  lstm_1 (LSTM)               (None, 32)                8320
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 14979 (58.51 KB)
# Trainable params: 14979 (58.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
train_predict=model.predict(x_train)
test_predict=model.predict(x_test)
# Out:
# 368/368 [==============================] - 2s 2ms/step
# 92/92 [==============================] - 0s 2ms/step

# %%
# print(train_predict.shape)
# tr_predict=np.zeros((train_predict.shape[0], 8))
# te_predict=np.zeros((test_predict.shape[0], 8))

# tr_predict[:,5]=train_predict.squeeze()
# te_predict[:,5]=test_predict.squeeze()
# print(tr_predict[0])
# print(tr_predict.shape,te_predict.shape)

# tr_predict=scaler.inverse_transform(tr_predict)
# tr_predict=[x[5] for x in tr_predict]


# te_predict=scaler.inverse_transform(te_predict)
# te_predict=[x[5] for x in te_predict]
# # print(te_predict)

# print(tr_predict[:5])
# print(te_predict[:5])

# %%
# def custom_accuracy(array1, array2):
#     total_elements = len(array1)
#     correct_matches = 0

#     for val1, val2 in zip(array1, array2):
#         if (val1 > 0 and val2 > 0) or (val1 < 0 and val2 < 0):
#             correct_matches += 1
#         elif val1 == 0 and val2 == 0:
#             correct_matches += 1

#     accuracy = correct_matches / total_elements
#     return accuracy

# # for i in tr_predict:
# #     if i <=0 :
# #         print('y')
# yT=np.zeros((y_train.shape[0], 8))
# yT[:,5]=y_train.squeeze()
# yT=scaler.inverse_transform(yT)
# yT=[x[5] for x in yT]

# yt=np.zeros((y_test.shape[0], 8))
# yt[:,5]=y_test.squeeze()
# yt=scaler.inverse_transform(yt)
# yt=[x[5] for x in yt]

# print(custom_accuracy(tr_predict,yT))
# print(custom_accuracy(te_predict,yt))
# print(tr_predict[:5], y_train[:5])

# %%
    
test_predict_argmax = np.argmax(test_predict, axis=1)
# 将真实标签转换为真实的类别索引
y_test_argmax = np.argmax(y_test, axis=1)
# 计算准确率
accuracy = np.mean(y_test_argmax == test_predict_argmax)
print("Accuracy test:", accuracy)

np.save('10_test.npy', test_predict_argmax)

train_predict_argmax = np.argmax(train_predict, axis=1)
# 将真实标签转换为真实的类别索引
y_train_argmax = np.argmax(y_train, axis=1)
# 计算准确率
accuracy = np.mean(y_train_argmax == train_predict_argmax)
print("Accuracy train:", accuracy)

np.save('10_train.npy', train_predict_argmax)


idx_l=[]
for idx, value in enumerate(train_predict_argmax):
    if value == 0:
        idx_l.append(idx)

# print(idx_l)
idx_ll=[]
for idx, value in enumerate(y_test_argmax):
    if value == 0:
        idx_ll.append(idx)

print(len(idx_l),len(idx_ll))
print(len(y_test_argmax))

##drop 0.2 兩次 step=6 RSI 8:30~10:30
# Accuracy test: 0.4788966691167937
# Accuracy train: 0.47840300210843956
#全時段
# Accuracy test: 0.4549774716169764
# Accuracy train: 0.45354446631858253
# Out:
# Accuracy test: 0.46976902173913043
# Accuracy train: 0.481100823919137
# 0 250
# 2944

# %%
print(history.history.keys())
plt.rcParams['font.sans-serif'] = ['SimHei', 'Arial']  # 可以指定多个字体备选
plt.rcParams['axes.unicode_minus'] = False  # 用于解决负号显示问题
# plot history
plt.figure(figsize=(7, 4))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# plot history
plt.figure(figsize=(7, 4))
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
